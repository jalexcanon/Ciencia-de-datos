# %% [markdown]
# <a href="https://colab.research.google.com/github/jalexcanon/MujeresDigitales/blob/master/Clase11(MD).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DataSets**

# %% [markdown]
# **Metodo 1 (Github)**

# %%
import pandas as pd

# %%
url = 'copied_raw_GH_link'
df1 = pd.read_csv(url)
# Traerlo de Github

# %% [markdown]
# **Método 2 (Local)**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bdb2252e-c950-46fa-af3d-ad617eb2a78b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdb2252e-c950-46fa-af3d-ad617eb2a78b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pokemon_data.csv to pokemon_data.csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['pokemon_data.csv']),sep=",")
df2.head(10)#sino le coloco nada me muestra las primeras 5 lineas
# Out:
#    #                       Name Type 1  ... Speed  Generation  Legendary
# 0  1                  Bulbasaur  Grass  ...    45           1      False
# 1  2                    Ivysaur  Grass  ...    60           1      False
# 2  3                   Venusaur  Grass  ...    80           1      False
# 3  3      VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4                 Charmander   Fire  ...    65           1      False
# 5  5                 Charmeleon   Fire  ...    80           1      False
# 6  6                  Charizard   Fire  ...   100           1      False
# 7  6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8  6  CharizardMega Charizard Y   Fire  ...   100           1      False
# 9  7                   Squirtle  Water  ...    43           1      False
#
# [10 rows x 12 columns]

# %%
df2.shape
# Out:
# (800, 12)

# %%
df2.tail(10) #imprime los 10 últimos valores (la cola)
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 790  714               Noibat   Flying  ...    55           6      False
# 791  715              Noivern   Flying  ...   123           6      False
# 792  716              Xerneas    Fairy  ...    99           6       True
# 793  717              Yveltal     Dark  ...    99           6       True
# 794  718     Zygarde50% Forme   Dragon  ...    95           6       True
# 795  719              Diancie     Rock  ...    50           6       True
# 796  719  DiancieMega Diancie     Rock  ...   110           6       True
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721            Volcanion     Fire  ...    70           6       True
#
# [10 rows x 12 columns]

# %%
df2['Type 1']
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
pk=df2['Type 1'].unique()
print(pk)
# Out:
# ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying']

# %%
for i in pk:
  print(i)
# Out:
# Grass
# Fire
# Water
# Bug
# Normal
# Poison
# Electric
# Ground
# Fairy
# Fighting
# Psychic
# Rock
# Ghost
# Ice
# Dragon
# Dark
# Steel
# Flying

# %%
df2.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
#Creando una nueva columna
df2['catched']=False
df2
# Out:
#             #                   Name   Type 1  ... Generation Legendary catched
# 0           1              Bulbasaur    Grass  ...          1     False   False
# 1           2                Ivysaur    Grass  ...          1     False   False
# 2           3               Venusaur    Grass  ...          1     False   False
# 3           3  VenusaurMega Venusaur    Grass  ...          1     False   False
# 4           4             Charmander     Fire  ...          1     False   False
# ...       ...                    ...      ...  ...        ...       ...     ...
# 796       719    DiancieMega Diancie     Rock  ...          6      True   False
# 797       720    HoopaHoopa Confined  Psychic  ...          6      True   False
# 798       720     HoopaHoopa Unbound  Psychic  ...          6      True   False
# 799       721              Volcanion     Fire  ...          6      True   False
# catched  True                   True     True  ...       True      True   False
#
# ...

# %%
df2.describe(include='all')
# Out:
#                  #       Name Type 1  ... Generation  Legendary  catched
# count   800.000000        800    800  ...  800.00000        800      800
# unique         NaN        800     18  ...        NaN          2        1
# top            NaN  Excadrill  Water  ...        NaN      False    False
# freq           NaN          1    112  ...        NaN        735      800
# mean    362.813750        NaN    NaN  ...    3.32375        NaN      NaN
# std     208.343798        NaN    NaN  ...    1.66129        NaN      NaN
# min       1.000000        NaN    NaN  ...    1.00000        NaN      NaN
# 25%     184.750000        NaN    NaN  ...    2.00000        NaN      NaN
# 50%     364.500000        NaN    NaN  ...    3.00000        NaN      NaN
# 75%     539.250000        NaN    NaN  ...    5.00000        NaN      NaN
# max     721.000000        NaN    NaN  ...    6.00000        NaN      NaN
#
# [11 rows x 13 columns]

# %%
#cambiando el valor de capturado de los pokemones de fuego(darle play a la celda que crea el catched)
mask=df2["Type 1"] == "Fire"
df2.loc[mask,"catched"]=True
print(df2.head(10))
# Out:
#    #                       Name Type 1  ... Generation Legendary catched
# 0  1                  Bulbasaur  Grass  ...          1     False   False
# 1  2                    Ivysaur  Grass  ...          1     False   False
# 2  3                   Venusaur  Grass  ...          1     False   False
# 3  3      VenusaurMega Venusaur  Grass  ...          1     False   False
# 4  4                 Charmander   Fire  ...          1     False    True
# 5  5                 Charmeleon   Fire  ...          1     False    True
# 6  6                  Charizard   Fire  ...          1     False    True
# 7  6  CharizardMega Charizard X   Fire  ...          1     False    True
# 8  6  CharizardMega Charizard Y   Fire  ...          1     False    True
# 9  7                   Squirtle  Water  ...          1     False   False
#
# [10 rows x 13 columns]

# %%
df2.loc[0:3,'Legendary']='Hola'
df2.loc[0:4,'Hola']='Hola' #Al no encontrar la columna "Hola" crea una
print(df2)
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  Hola
# 0      1              Bulbasaur    Grass  ...          1       Hola  Hola
# 1      2                Ivysaur    Grass  ...          1       Hola  Hola
# 2      3               Venusaur    Grass  ...          1       Hola  Hola
# 3      3  VenusaurMega Venusaur    Grass  ...          1       Hola  Hola
# 4      4             Charmander     Fire  ...          1      False  Hola
# ..   ...                    ...      ...  ...        ...        ...   ...
# 795  719                Diancie     Rock  ...          6       True   NaN
# 796  719    DiancieMega Diancie     Rock  ...          6       True   NaN
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True   NaN
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True   NaN
# 799  721              Volcanion     Fire  ...          6       True   NaN
#
# [800 rows x 13 columns]

# %%
df2['Type 1']=='Fire'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799     True
# Name: Type 1, Length: 800, dtype: bool

# %%
df2.loc[df2['Type 1']=='Fire',:] #Los muestra todos
# Out:
#        #                       Name Type 1  ... Generation  Legendary  Hola
# 4      4                 Charmander   Fire  ...          1      False  Hola
# 5      5                 Charmeleon   Fire  ...          1      False   NaN
# 6      6                  Charizard   Fire  ...          1      False   NaN
# 7      6  CharizardMega Charizard X   Fire  ...          1      False   NaN
# 8      6  CharizardMega Charizard Y   Fire  ...          1      False   NaN
# 42    37                     Vulpix   Fire  ...          1      False   NaN
# 43    38                  Ninetales   Fire  ...          1      False   NaN
# 63    58                  Growlithe   Fire  ...          1      False   NaN
# 64    59                   Arcanine   Fire  ...          1      False   NaN
# 83    77                     Ponyta   Fire  ...          1      False   NaN
# 84    78                   Rapidash   Fire  ...          1      False   NaN
# ...

# %%
print(df2.drop(labels="Hola",axis=1,inplace=True)) #eliminar valores nulos (1:15:00) (ver inplace y drop)

# %%
df2.loc[(df2['Type 1']=='Fire')| (df2['Type 1']=='Grass'),:] #Trae los dos tipos
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur  Grass  ...    45           1       Hola
# 1      2                Ivysaur  Grass  ...    60           1       Hola
# 2      3               Venusaur  Grass  ...    80           1       Hola
# 3      3  VenusaurMega Venusaur  Grass  ...    80           1       Hola
# 4      4             Charmander   Fire  ...    65           1      False
# ..   ...                    ...    ...  ...   ...         ...        ...
# 735  667                 Litleo   Fire  ...    72           6      False
# 736  668                 Pyroar   Fire  ...   106           6      False
# 740  672                 Skiddo  Grass  ...    52           6      False
# 741  673                 Gogoat  Grass  ...    68           6      False
# 799  721              Volcanion   Fire  ...    70           6       True
#
# [122 rows x 12 columns]

# %%
df2['catched']=False
df2.head(2)
# Out:
#    #       Name Type 1  Type 2  ...  Speed  Generation  Legendary  catched
# 0  1  Bulbasaur  Grass  Poison  ...     45           1       Hola    False
# 1  2    Ivysaur  Grass  Poison  ...     60           1       Hola    False
#
# [2 rows x 13 columns]

# %%
df2.loc[df2['Type 1'] == 'Grass','catched'] =True
df2.head(2)
# Out:
#    #       Name Type 1  Type 2  ...  Speed  Generation  Legendary  catched
# 0  1  Bulbasaur  Grass  Poison  ...     45           1       Hola     True
# 1  2    Ivysaur  Grass  Poison  ...     60           1       Hola     True
#
# [2 rows x 13 columns]

# %%
def_type=df2['Type 1'].unique()

# %%
for i in def_type:
  df2.loc[df2['Type 1'] == i,'catched'] =True
  print(df2)
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  catched
# 0      1              Bulbasaur    Grass  ...          1       Hola     True
# 1      2                Ivysaur    Grass  ...          1       Hola     True
# 2      3               Venusaur    Grass  ...          1       Hola     True
# 3      3  VenusaurMega Venusaur    Grass  ...          1       Hola     True
# 4      4             Charmander     Fire  ...          1      False     True
# ..   ...                    ...      ...  ...        ...        ...      ...
# 795  719                Diancie     Rock  ...          6       True     True
# 796  719    DiancieMega Diancie     Rock  ...          6       True     True
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True     True
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True     True
# 799  721              Volcanion     Fire  ...          6       True     True
#
# [800 rows x 13 columns]
# ...

# %%
#otra forma, sin crear una variable
for i in df2['Type 1'].unique():
  df2.loc[df2['Type 1'] == i,'catched'] =True
  print(df2)
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  catched
# 0      1              Bulbasaur    Grass  ...          1       Hola     True
# 1      2                Ivysaur    Grass  ...          1       Hola     True
# 2      3               Venusaur    Grass  ...          1       Hola     True
# 3      3  VenusaurMega Venusaur    Grass  ...          1       Hola     True
# 4      4             Charmander     Fire  ...          1      False     True
# ..   ...                    ...      ...  ...        ...        ...      ...
# 795  719                Diancie     Rock  ...          6       True     True
# 796  719    DiancieMega Diancie     Rock  ...          6       True     True
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True     True
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True     True
# 799  721              Volcanion     Fire  ...          6       True     True
#
# [800 rows x 13 columns]
# ...

# %% [markdown]
# **Método 3 (Drive)**

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
# Establecer ruta de acceso en drive
import os
print(os.getcwd())
os.chdir("/content/gdrive/My Drive")
